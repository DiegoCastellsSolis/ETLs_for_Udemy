# %%
import pandas as pd
import os

# %%
# Crear un conjunto de datos con 5 experiencias por país
data = {
    "ID de Experiencia": list(range(1, 21)),  # 20 experiencias en total
    "Experiencia": [
        # Argentina
        "Cena gourmet en un restaurante de lujo",
        "Escapada de fin de semana a la playa",
        "Clase de cocina internacional",
        "Trekking en la montaña",
        "Tour enológico por viñedos",
        
        # Chile
        "Cata de vinos en el Valle del Maipo",
        "Día de spa en Santiago",
        "Paseo por el desierto de Atacama",
        "Tour por el Parque Nacional Torres del Paine",
        "Clase de surf en Pichilemu",
        
        # Uruguay
        "Clase de cata de vinos",
        "Día de campo en la rural",
        "Excursión a Colonia del Sacramento",
        "Taller de arte en Montevideo",
        "Clase de cocina uruguaya",
        
        # Perú
        "Clase de cocina peruana",
        "Tour a Machu Picchu",
        "Cata de pisco en Ica",
        "Recorrido gastronómico en Lima",
        "Trekking por el Valle Sagrado",
    ],
    "Categoría": [
        # Argentina
        "Gastronomía", "Aventura", "Culinaria", "Aventura", "Cultural",
        
        # Chile
        "Cultural", "Bienestar", "Aventura", "Aventura", "Aventura",
        
        # Uruguay
        "Cultural", "Aventura", "Cultural", "Cultural", "Culinaria",
        
        # Perú
        "Culinaria", "Aventura", "Cultural", "Culinaria", "Aventura",
    ],
    "Ubicación": [
        # Argentina
        "Buenos Aires", "Viña del Mar", "Córdoba", "Mendoza", "San Juan",
        
        # Chile
        "Santiago", "Santiago", "San Pedro", "Puerto Natales", "Pichilemu",
        
        # Uruguay
        "Montevideo", "Durazno", "Colonia del Sacramento", "Montevideo", "Montevideo",
        
        # Perú
        "Lima", "Cusco", "Ica", "Lima", "Cusco",
    ],
    "País": [
        "Argentina"] * 5 + [
        "Chile"] * 5 + [
        "Uruguay"] * 5 + [
        "Perú"] * 5
    ,
    "Duración": [
        "2 horas", "2 días", "3 horas", "1 día", "6 horas",
        "3 horas", "1 día", "5 horas", "3 días", "2 horas",
        "1 día", "1 día", "3 horas", "2 horas", "3 horas",
        "3 horas", "4 días", "3 horas", "1 día", "3 días"
    ],
    "Precio": [
        150, 300, 75, 100, 120,
        200, 150, 200, 400, 100,
        75, 80, 100, 90, 150,
        50, 600, 80, 100, 200,
    ],
    "Disponibilidad": [
        "Todo el año", "Verano", "Todo el año", "Primavera", "Todo el año",
        "Todo el año", "Todo el año", "Todo el año", "Todo el año", "Verano",
        "Todo el año", "Otoño", "Todo el año", "Todo el año", "Primavera",
        "Todo el año", "Todo el año", "Todo el año", "Todo el año", "Primavera",
    ]
}

# %%
# Crear la carpeta si no existe
path_target = './data/experiencias_por_pais.csv'
os.makedirs(os.path.dirname(path_target), exist_ok=True)
# Crear un DataFrame
df = pd.DataFrame(data)

# Guardar el DataFrame como un archivo CSV 
df.to_csv(path_target, index=False)
# Out:
# './data/experiencias_por_pais.csv'

# %%
df
# Out:
#     ID de Experiencia                                   Experiencia  \
# 0                   1        Cena gourmet en un restaurante de lujo
# 1                   2          Escapada de fin de semana a la playa
# 2                   3                 Clase de cocina internacional
# 3                   4                        Trekking en la montaña
# 4                   5                    Tour enológico por viñedos
# 5                   6           Cata de vinos en el Valle del Maipo
# 6                   7                        Día de spa en Santiago
# 7                   8              Paseo por el desierto de Atacama
# 8                   9  Tour por el Parque Nacional Torres del Paine
# 9                  10                    Clase de surf en Pichilemu
# 10                 11                        Clase de cata de vinos
# 11                 12                      Día de campo en la rural
# 12                 13            Excursión a Colonia del Sacramento
# ...
